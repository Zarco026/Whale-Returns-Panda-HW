# %%
#Initial imports

import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path
# %matplotlib inline

# %%
# Reading whale returns
whale_returns_csv = Path(r"C:\Users\Sejas\Desktop\FinTech\Homeworks\Pandas HW\Whale Returns Pandas HW\Whales_Returns.csv")
whale_returns = pd.read_csv(whale_returns_csv, index_col="Date", parse_dates=True, infer_datetime_format=True)
# whale_returns.describe()
whale_returns.sort_index(ascending = True, inplace = True)
whale_returns.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                        NaN                 NaN
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-02                          NaN                     NaN
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726
# 2015-03-06                    -0.008481               -0.013098

# %%
# Count nulls
print(whale_returns.isnull().sum())
print(whale_returns[whale_returns.isnull().any(axis = 1)])
# Out:
# SOROS FUND MANAGEMENT LLC      1
# PAULSON & CO.INC.              1
# TIGER GLOBAL MANAGEMENT LLC    1
# BERKSHIRE HATHAWAY INC         1
# dtype: int64
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                        NaN                 NaN
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-02                          NaN                     NaN

# %%
# Drop Nulls
whale_returns.dropna(inplace=True)
whale_returns.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      0
# PAULSON & CO.INC.              0
# TIGER GLOBAL MANAGEMENT LLC    0
# BERKSHIRE HATHAWAY INC         0
# dtype: int64

# %%
# Reading algorithmic returns
algo_returns_csv = Path(r"C:\Users\Sejas\Desktop\FinTech\Homeworks\Pandas HW\Whale Returns Pandas HW\Algo_Returns.csv")
algo_returns = pd.read_csv(algo_returns_csv, index_col = "Date", parse_dates = True, infer_datetime_format = True)
algo_returns.sort_index(ascending = True, inplace = True)
algo_returns.head(100)
# Out:
#               Algo 1    Algo 2
# Date
# 2014-05-28  0.001745       NaN
# 2014-05-29  0.003978       NaN
# 2014-05-30  0.004464       NaN
# 2014-06-02  0.005692       NaN
# 2014-06-03  0.005292       NaN
# ...              ...       ...
# 2014-10-10 -0.012612 -0.011752
# 2014-10-13 -0.018528 -0.002009
# 2014-10-14  0.000702  0.004501
# 2014-10-15  0.021616 -0.000977
# 2014-10-16  0.098246  0.083734
#
# [100 rows x 2 columns]

# %%
# Count Nulls
algo_returns.isnull().sum()
# Out:
# Algo 1    0
# Algo 2    6
# dtype: int64

# %%
# Drop Nulls
algo_returns.dropna(inplace = True)
algo_returns.head()
# Out:
#               Algo 1    Algo 2
# Date
# 2014-06-05  0.004062  0.013285
# 2014-06-06  0.001857  0.008284
# 2014-06-09 -0.005012  0.005668
# 2014-06-10  0.004406 -0.000735
# 2014-06-11  0.004760 -0.003761

# %%
# Reading S&P 500 Closing Prices, sorting index
sp500_history_csv = Path(r"C:\Users\Sejas\Desktop\FinTech\Homeworks\Pandas HW\Whale Returns Pandas HW\SP500_History.csv")
sp500_history = pd.read_csv(sp500_history_csv, index_col = "Date", parse_dates = True, infer_datetime_format = True)
sp500_history.sort_index(ascending = True, inplace = True)
sp500_history
# Out:
#                Close
# Date
# 2012-10-01  $1444.49
# 2012-10-02  $1445.75
# 2012-10-03  $1450.99
# 2012-10-04  $1461.40
# 2012-10-05  $1460.93
# ...              ...
# 2019-04-16  $2907.06
# 2019-04-17  $2900.45
# 2019-04-18  $2905.03
# 2019-04-22  $2907.97
# 2019-04-23  $2933.68
#
# [1649 rows x 1 columns]

# %%
# Check Data Types
sp500_history.dtypes
# Out:
# Close    object
# dtype: object

# %%
# Fix Data Types
sp500_history["Close"] = sp500_history["Close"].str.replace('$','').astype("float")
sp500_history.sort_index(inplace = True)
sp500_history
# Out:
# C:\Users\Sejas\anaconda3\envs\dev\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#               Close
# Date
# 2012-10-01  1444.49
# 2012-10-02  1445.75
# 2012-10-03  1450.99
# 2012-10-04  1461.40
# 2012-10-05  1460.93
# ...             ...
# 2019-04-16  2907.06
# 2019-04-17  2900.45
# 2019-04-18  2905.03
# 2019-04-22  2907.97
# 2019-04-23  2933.68
#
# [1649 rows x 1 columns]

# %%
# Calculate Daily Returns
sp500_daily_returns = sp500_history.pct_change()

# %%
# Drop Nulls
sp500_daily_returns.dropna(inplace = True)
sp500_daily_returns.head()
# Out:
#                Close
# Date
# 2012-10-02  0.000872
# 2012-10-03  0.003624
# 2012-10-04  0.007174
# 2012-10-05 -0.000322
# 2012-10-08 -0.003457

# %%
# Rename Column
sp500_daily_returns.rename(columns = {"Close":"SP500"}, inplace = True)

# %%
# Concentrate all DataFrames into a single DataFrame
df_daily = pd.concat([whale_returns, algo_returns, sp500_daily_returns], axis = "columns",join = "inner")

# %%
# Plot daily returns
df_daily.plot(figsize = (20,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df_cum = (1+ df_daily).cumprod()
df_cum.plot(figsize = (20,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# Box plot to visually show risk
df_daily.plot(kind = "box", figsize = (20,10))
# Out:
# <AxesSubplot:>

# %%
# Daily Standard Deviations
# Calculate the standard deviation for each portfolio. Which portfolios are riskier than the S&P 500?
df_daily_std = pd.DataFrame(df_daily.std()).rename(columns = {0:"std"})
df_daily_std
# Out:
#                                   std
# SOROS FUND MANAGEMENT LLC    0.007895
# PAULSON & CO.INC.            0.007023
# TIGER GLOBAL MANAGEMENT LLC  0.010894
# BERKSHIRE HATHAWAY INC       0.012919
# Algo 1                       0.007620
# Algo 2                       0.008342
# SP500                        0.008554

# %%
# Determine which portfolios are riskier than the S&P 500
higher_std = df_daily_std[df_daily_std["std"] > df_daily_std.loc["SP500", "std"]]
higher_std
# Out:
#                                   std
# TIGER GLOBAL MANAGEMENT LLC  0.010894
# BERKSHIRE HATHAWAY INC       0.012919

# %%
# Calculate the annualized standard deviation (252 trading days)
df_annualized_std = df_daily_std*np.sqrt(252)
df_annualized_std
# Out:
#                                   std
# SOROS FUND MANAGEMENT LLC    0.125335
# PAULSON & CO.INC.            0.111488
# TIGER GLOBAL MANAGEMENT LLC  0.172936
# BERKSHIRE HATHAWAY INC       0.205077
# Algo 1                       0.120967
# Algo 2                       0.132430
# SP500                        0.135786

# %%
# Calculate and plot the rolling standard deviation for the S&PP 500 using a 21 day window
sp500_rolling_21 = df_daily[["SP500"]].rolling(window = 21).std()
sp500_rolling_21.plot(figsize = (20,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# Correlation
correlation_sp500 = pd.DataFrame(df_daily.corr()).loc[:,"SP500"]
correlation_sp500[correlation_sp500==correlation_sp500[correlation_sp500<1].max()]
# Out:
# Algo 2    0.858764
# Name: SP500, dtype: float64

# %%
df_daily.plot(kind="scatter", y = "Algo 2", x = "SP500", figsize = (20,10))
# Out:
# <AxesSubplot:xlabel='SP500', ylabel='Algo 2'>

# %%
# Calculate Beta for a single portfolio compared to the total market (S&P 500)
rolling_covariance = df_daily['BERKSHIRE HATHAWAY INC'].rolling(window=60).cov(df_daily['SP500'])
rolling_variance = df_daily['SP500'].rolling(window=60).var()
rolling_beta = rolling_covariance / rolling_variance
rolling_beta.plot(figsize=(20, 10), title='Rolling 60-Day Beta of BH')
# Out:
# <AxesSubplot:title={'center':'Rolling 60-Day Beta of BH'}, xlabel='Date'>

# %%
df_daily_ewm = df_daily.ewm(span = 21,adjust = False).mean()
(1+df_daily_ewm).cumprod().plot(figsize = (20,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# Annualzied Sharpe Ratios
sharpe_ratios = df_daily.mean()*252/(df_daily.std()*np.sqrt(252))
sharpe_ratios
# Out:
# SOROS FUND MANAGEMENT LLC      0.356417
# PAULSON & CO.INC.             -0.483570
# TIGER GLOBAL MANAGEMENT LLC   -0.121060
# BERKSHIRE HATHAWAY INC         0.621810
# Algo 1                         1.378648
# Algo 2                         0.501364
# SP500                          0.648267
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
sharpe_ratios.plot(kind = "bar", title = "Sharpe Ratios")
# Out:
# <AxesSubplot:title={'center':'Sharpe Ratios'}>

# %%
# Read the first stock
aapl_historical = pd.read_csv(Path(r"C:\Users\Sejas\Desktop\FinTech\Homeworks\Pandas HW\Whale Returns Pandas HW\AAPL Historical-checkpoint.csv"), index_col = "Trade DATE",
                           parse_dates = True, infer_datetime_format = True)
aapl_historical.rename(columns = {"Close":"aapl"}, inplace = True)
aapl_historical.head()
# Out:
#            Symbol    NOCP
# Trade DATE
# 2019-05-09   AAPL  200.72
# 2019-05-08   AAPL  202.90
# 2019-05-07   AAPL  202.86
# 2019-05-06   AAPL  208.48
# 2019-05-03   AAPL  211.75

# %%
# Read the second stock
cost_historical = pd.read_csv(Path(r"C:\Users\Sejas\Desktop\FinTech\Homeworks\Pandas HW\Whale Returns Pandas HW\COST HISTORICAL-checkpoint.csv"), index_col="Trade DATE", 
                           parse_dates = True, infer_datetime_format= True)
cost_historical.rename(columns = {"Close":"goog"}, inplace = True)
cost_historical.head()
# Out:
#            Symbol    NOCP
# Trade DATE
# 2019-05-09   COST  243.47
# 2019-05-08   COST  241.34
# 2019-05-07   COST  240.18
# 2019-05-06   COST  244.23
# 2019-05-03   COST  244.62

# %%
# Read the third stock
goog_history = pd.read_csv(Path(r"C:\Users\Sejas\Desktop\FinTech\Homeworks\Pandas HW\Whale Returns Pandas HW\Google Historical.csv"), index_col="Trade DATE", 
                           parse_dates = True, infer_datetime_format= True)
goog_history.rename(columns = {"Close":"goog"}, inplace = True)
goog_history.head()
# Out:
#            Symbol     NOCP
# Trade DATE
# 2019-05-09   GOOG  1162.38
# 2019-05-08   GOOG  1166.27
# 2019-05-07   GOOG  1174.10
# 2019-05-06   GOOG  1189.39
# 2019-05-03   GOOG  1185.40

# %%
# Combine All Stocks In A Single Frame
my_stocks = pd.concat([aapl_historical, cost_historical, goog_history], axis = "rows", join= "inner")
my_stocks.sort_index(ascending = True, inplace = True)
my_stocks.head()
# Out:
#            Symbol     NOCP
# Trade DATE
# 2018-05-11   GOOG  1098.26
# 2018-05-11   AAPL   188.59
# 2018-05-11   COST   195.76
# 2018-05-14   AAPL   188.15
# 2018-05-14   COST   195.88

# %%
# Reset the index
# my_stocks.index = my_stocks.index.normalize()
my_stocks=my_stocks.reset_index()
my_stocks.head()
# Out:
#   Trade DATE Symbol     NOCP
# 0 2018-05-11   GOOG  1098.26
# 1 2018-05-11   AAPL   188.59
# 2 2018-05-11   COST   195.76
# 3 2018-05-14   AAPL   188.15
# 4 2018-05-14   COST   195.88

# %%
my_portfolio=my_stocks.pivot_table(values= "NOCP", index="Trade DATE", columns="Symbol")
my_portfolio.head()
#Drop Nulls
#my_stocks.dropna(inplace=True)
#my_stocks
# Out:
# Symbol        AAPL    COST     GOOG
# Trade DATE
# 2018-05-11  188.59  195.76  1098.26
# 2018-05-14  188.15  195.88  1100.20
# 2018-05-15  186.44  195.48  1079.23
# 2018-05-16  188.18  198.71  1081.77
# 2018-05-17  186.99  199.60  1078.59

# %%
# Calculate weighted portfolio returns
weights = [1/3, 1/3, 1/3]
#my_portfolio = my_stocks.dot(weights)
my_portfolio = my_portfolio.pct_change()
my_portfolio.dropna(inplace=True)
my_portfolio.head()
# Out:
# Symbol          AAPL      COST      GOOG
# Trade DATE
# 2018-05-14 -0.002333  0.000613  0.001766
# 2018-05-15 -0.009088 -0.002042 -0.019060
# 2018-05-16  0.009333  0.016523  0.002354
# 2018-05-17 -0.006324  0.004479 -0.002940
# 2018-05-18 -0.003637 -0.003206 -0.011339

# %%
my_portfolio = pd.concat((my_portfolio,df_daily), axis = 1, join = "inner")
my_portfolio.rename(columns = {0:"my_portfolio"}, inplace = True)
my_portfolio
# Out:
#                 AAPL      COST      GOOG  SOROS FUND MANAGEMENT LLC  \
# 2018-05-14 -0.002333  0.000613  0.001766                   0.000000
# 2018-05-15 -0.009088 -0.002042 -0.019060                  -0.000726
# 2018-05-16  0.009333  0.016523  0.002354                   0.008637
# 2018-05-17 -0.006324  0.004479 -0.002940                  -0.001955
# 2018-05-18 -0.003637 -0.003206 -0.011339                  -0.004357
# ...              ...       ...       ...                        ...
# 2019-04-16  0.000100 -0.004019  0.004938                   0.002699
# 2019-04-17  0.019473  0.000897  0.007505                  -0.002897
# 2019-04-18  0.003594  0.001018  0.000024                   0.001448
# 2019-04-22  0.003287 -0.009723  0.010086                  -0.002586
# 2019-04-23  0.014423  0.008874  0.012580                   0.007167
#
#             PAULSON & CO.INC.   TIGER GLOBAL MANAGEMENT LLC  \
# 2018-05-14            0.000000                     0.000000
# ...

# %%
# Only compare dates where return data exists for all the stocks (drop NaNs)
my_portfolio.dropna(inplace=True)
my_portfolio
# Out:
#                 AAPL      COST      GOOG  SOROS FUND MANAGEMENT LLC  \
# 2018-05-14 -0.002333  0.000613  0.001766                   0.000000
# 2018-05-15 -0.009088 -0.002042 -0.019060                  -0.000726
# 2018-05-16  0.009333  0.016523  0.002354                   0.008637
# 2018-05-17 -0.006324  0.004479 -0.002940                  -0.001955
# 2018-05-18 -0.003637 -0.003206 -0.011339                  -0.004357
# ...              ...       ...       ...                        ...
# 2019-04-16  0.000100 -0.004019  0.004938                   0.002699
# 2019-04-17  0.019473  0.000897  0.007505                  -0.002897
# 2019-04-18  0.003594  0.001018  0.000024                   0.001448
# 2019-04-22  0.003287 -0.009723  0.010086                  -0.002586
# 2019-04-23  0.014423  0.008874  0.012580                   0.007167
#
#             PAULSON & CO.INC.   TIGER GLOBAL MANAGEMENT LLC  \
# 2018-05-14            0.000000                     0.000000
# ...

# %%
# Risk
my_portfolio_std = pd.DataFrame(my_portfolio.std()).rename(columns = {0:"std"})
my_portfolio_std
# Out:
#                                   std
# AAPL                         0.018706
# COST                         0.013357
# GOOG                         0.016095
# SOROS FUND MANAGEMENT LLC    0.009240
# PAULSON & CO.INC.            0.007353
# TIGER GLOBAL MANAGEMENT LLC  0.014648
# BERKSHIRE HATHAWAY INC       0.015569
# Algo 1                       0.008423
# Algo 2                       0.008791
# SP500                        0.009578

# %%
higher_std = my_portfolio_std[my_portfolio_std["std"] > my_portfolio_std.loc["SP500", "std"]]
higher_std
# Out:
#                                   std
# AAPL                         0.018706
# COST                         0.013357
# GOOG                         0.016095
# TIGER GLOBAL MANAGEMENT LLC  0.014648
# BERKSHIRE HATHAWAY INC       0.015569

# %%
# Rolling
my_portfolio_rolling_15 = my_portfolio.rolling(window = 15).std()
my_portfolio_rolling_60 = my_portfolio.rolling(window = 60).std()
my_portfolio_rolling_120 = my_portfolio.rolling(window = 120).std()
ax = my_portfolio_rolling_15.plot(figsize = (20,10), title = 'my portfolio std')
my_portfolio_rolling_60.plot(ax = ax)
my_portfolio_rolling_120.plot(ax = ax)
ax.legend(['rolling_15','rolling_60','rolling_120'])

# %%
my_portfolio_rolling_15_returns = my_portfolio_std.rolling(window = 15).mean()
my_portfolio_rolling_60_returns = my_portfolio_std.rolling(window = 60).mean()
my_portfolio_rolling_120_returns = my_portfolio_std.rolling(window = 120).mean()
ax=my_portfolio_rolling_15_returns.plot(figsize = (20,10), title = 'My Portfolio Std')
ax=my_portfolio_rolling_60_returns.plot(ax=ax)
ax=my_portfolio_rolling_120_returns.plot(ax=ax)
ax.legend(['rolling 15','rolling 60','rolling 120'])

# %%
# Beta
rolling_covariance = my_portfolio.rolling(window=60).cov(my_portfolio["SP500"])
rolling_variance = my_portfolio["SP500"].rolling(window=60).var()
#rolling_beta = rolling_covariance / rolling_variance
rolling_beta.plot(figsize=(20,10), title= "Rolling 60-Day Beta Of My Portfolio")
# Out:
# <AxesSubplot:title={'center':'Rolling 60-Day Beta Of My Portfolio'}, xlabel='Date'>

# %%
# Annualzied Sharpe Ratios
trading_days = my_portfolio.count()
sharpe_ratios = my_portfolio.mean()*trading_days/(my_portfolio.std()*np.sqrt(trading_days))

# %%
# Visualize the sharpe ratios as a bar plot
sharpe_ratios.plot(kind = 'bar', title = "sharpe_ratios")
# Out:
# <AxesSubplot:title={'center':'sharpe_ratios'}>
